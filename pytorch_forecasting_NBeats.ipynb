# %%
import os
import warnings

warnings.filterwarnings("ignore")

os.chdir("../../..")

# %%
import pandas as pd
import pytorch_lightning as pl
from pytorch_lightning.callbacks import EarlyStopping
import torch

from pytorch_forecasting import Baseline, NBeats, TimeSeriesDataSet
from pytorch_forecasting.data import NaNLabelEncoder
from pytorch_forecasting.data.examples import generate_ar_data
from pytorch_forecasting.metrics import SMAPE

# %%
data = generate_ar_data(seasonality=10.0, timesteps=400, n_series=100, seed=42)
data["static"] = 2
data["date"] = pd.Timestamp("2020-01-01") + pd.to_timedelta(data.time_idx, "D")
data.head()
# Out:
#    series  time_idx     value  static       date
# 0       0         0 -0.000000       2 2020-01-01
# 1       0         1 -0.046501       2 2020-01-02
# 2       0         2 -0.097796       2 2020-01-03
# 3       0         3 -0.144397       2 2020-01-04
# 4       0         4 -0.177954       2 2020-01-05

# %%
# create dataset and dataloaders
max_encoder_length = 60
max_prediction_length = 20

training_cutoff = data["time_idx"].max() - max_prediction_length

context_length = max_encoder_length
prediction_length = max_prediction_length

training = TimeSeriesDataSet(
    data[lambda x: x.time_idx <= training_cutoff],
    time_idx="time_idx",
    target="value",
    categorical_encoders={"series": NaNLabelEncoder().fit(data.series)},
    group_ids=["series"],
    # only unknown variable is "value" - and N-Beats can also not take any additional variables
    time_varying_unknown_reals=["value"],
    max_encoder_length=context_length,
    max_prediction_length=prediction_length,
)

validation = TimeSeriesDataSet.from_dataset(training, data, min_prediction_idx=training_cutoff + 1)
batch_size = 128
train_dataloader = training.to_dataloader(train=True, batch_size=batch_size, num_workers=0)
val_dataloader = validation.to_dataloader(train=False, batch_size=batch_size, num_workers=0)

# %%
# calculate baseline absolute error
actuals = torch.cat([y[0] for x, y in iter(val_dataloader)])
baseline_predictions = Baseline().predict(val_dataloader)
SMAPE()(baseline_predictions, actuals)
# Out:
# tensor(0.5462)

# %%
pl.seed_everything(42)
trainer = pl.Trainer(gpus=0, gradient_clip_val=0.1)
net = NBeats.from_dataset(training, learning_rate=3e-2, weight_decay=1e-2, widths=[32, 512], backcast_loss_ratio=0.1)
# Out:
# Global seed set to 42
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores

# %%
# find optimal learning rate
res = trainer.tuner.lr_find(net, train_dataloader=train_dataloader, val_dataloaders=val_dataloader, min_lr=1e-5)
print(f"suggested learning rate: {res.suggestion()}")
fig = res.plot(show=True, suggest=True)
fig.show()
net.hparams.learning_rate = res.suggestion()
# Out:
#   | Name            | Type       | Params
# -----------------------------------------------
# 0 | loss            | MASE       | 0
# 1 | logging_metrics | ModuleList | 0
# 2 | net_blocks      | ModuleList | 1.7 M
# -----------------------------------------------
# 1.7 M     Trainable params
# 0         Non-trainable params
# 1.7 M     Total params
# 6.851     Total estimated model params size (MB)
# Global seed set to 42
# Finding best initial lr:  99%|█████████▉| 99/100 [00:22<00:00,  4.47it/s]
# LR finder stopped early after 99 steps due to diverging loss.
# Restored states from the checkpoint file at e:\lr_find_temp_model.ckpt
# suggested learning rate: 0.001778279410038923

# %%
early_stop_callback = EarlyStopping(monitor="val_loss", min_delta=1e-4, patience=10, verbose=False, mode="min")
trainer = pl.Trainer(
    max_epochs=100,
    gpus=0,
    weights_summary="top",
    gradient_clip_val=0.1,
    callbacks=[early_stop_callback],
    limit_train_batches=30,
)


net = NBeats.from_dataset(
    training,
    learning_rate=4e-3,
    log_interval=10,
    log_val_interval=1,
    weight_decay=1e-2,
    widths=[32, 512],
    backcast_loss_ratio=1.0,
)

trainer.fit(
    net,
    train_dataloader=train_dataloader,
    val_dataloaders=val_dataloader,
)
# Out:
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
#
#   | Name            | Type       | Params
# -----------------------------------------------
# 0 | loss            | MASE       | 0
# 1 | logging_metrics | ModuleList | 0
# 2 | net_blocks      | ModuleList | 1.7 M
# -----------------------------------------------
# 1.7 M     Trainable params
# 0         Non-trainable params
# 1.7 M     Total params
# 6.851     Total estimated model params size (MB)
#                                                                       Global seed set to 42
# Epoch 0:  97%|█████████▋| 30/31 [00:08<00:00,  3.49it/s, loss=2.57, v_num=0, val_loss=3.280, train_loss_step=1.780]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 0: 100%|██████████| 31/31 [00:09<00:00,  3.37it/s, loss=2.57, v_num=0, val_loss=1.470, train_loss_step=1.720, train_loss_epoch=3.140]
# Epoch 1:  97%|█████████▋| 30/31 [00:08<00:00,  3.50it/s, loss=1.43, v_num=0, val_loss=1.470, train_loss_step=1.390, train_loss_epoch=3.140]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 1: 100%|██████████| 31/31 [00:09<00:00,  3.38it/s, loss=1.43, v_num=0, val_loss=1.140, train_loss_step=1.300, train_loss_epoch=1.520]
# Epoch 2:  97%|█████████▋| 30/31 [00:08<00:00,  3.60it/s, loss=1.27, v_num=0, val_loss=1.140, train_loss_step=1.280, train_loss_epoch=1.520]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 2: 100%|██████████| 31/31 [00:09<00:00,  3.44it/s, loss=1.27, v_num=0, val_loss=1.010, train_loss_step=1.220, train_loss_epoch=1.290]
# Epoch 3:  97%|█████████▋| 30/31 [00:08<00:00,  3.43it/s, loss=1.17, v_num=0, val_loss=1.010, train_loss_step=1.140, train_loss_epoch=1.290]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 3: 100%|██████████| 31/31 [00:09<00:00,  3.28it/s, loss=1.17, v_num=0, val_loss=0.918, train_loss_step=1.130, train_loss_epoch=1.180]
# Epoch 4:  97%|█████████▋| 30/31 [00:08<00:00,  3.54it/s, loss=1.12, v_num=0, val_loss=0.918, train_loss_step=1.100, train_loss_epoch=1.180]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 4: 100%|██████████| 31/31 [00:09<00:00,  3.43it/s, loss=1.12, v_num=0, val_loss=0.894, train_loss_step=1.090, train_loss_epoch=1.120]
# Epoch 5:  97%|█████████▋| 30/31 [00:08<00:00,  3.34it/s, loss=1.09, v_num=0, val_loss=0.894, train_loss_step=1.100, train_loss_epoch=1.120]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 5: 100%|██████████| 31/31 [00:09<00:00,  3.24it/s, loss=1.09, v_num=0, val_loss=0.881, train_loss_step=1.070, train_loss_epoch=1.090]
# Epoch 6:  97%|█████████▋| 30/31 [00:08<00:00,  3.51it/s, loss=1.06, v_num=0, val_loss=0.881, train_loss_step=1.000, train_loss_epoch=1.090]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 6: 100%|██████████| 31/31 [00:09<00:00,  3.37it/s, loss=1.06, v_num=0, val_loss=0.838, train_loss_step=1.040, train_loss_epoch=1.060]
# Epoch 7:  97%|█████████▋| 30/31 [00:08<00:00,  3.68it/s, loss=1.04, v_num=0, val_loss=0.838, train_loss_step=0.989, train_loss_epoch=1.060]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 7: 100%|██████████| 31/31 [00:08<00:00,  3.55it/s, loss=1.04, v_num=0, val_loss=0.823, train_loss_step=1.020, train_loss_epoch=1.040]
# Epoch 8:  97%|█████████▋| 30/31 [00:08<00:00,  3.61it/s, loss=1.01, v_num=0, val_loss=0.823, train_loss_step=1.000, train_loss_epoch=1.040]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 8: 100%|██████████| 31/31 [00:08<00:00,  3.48it/s, loss=1.01, v_num=0, val_loss=0.822, train_loss_step=0.962, train_loss_epoch=1.020]
# Epoch 9:  97%|█████████▋| 30/31 [00:08<00:00,  3.72it/s, loss=0.998, v_num=0, val_loss=0.822, train_loss_step=0.974, train_loss_epoch=1.020]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 9: 100%|██████████| 31/31 [00:08<00:00,  3.55it/s, loss=0.998, v_num=0, val_loss=0.824, train_loss_step=0.979, train_loss_epoch=1.000]
# Epoch 10:  97%|█████████▋| 30/31 [00:08<00:00,  3.57it/s, loss=0.999, v_num=0, val_loss=0.824, train_loss_step=1.000, train_loss_epoch=1.000]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 10: 100%|██████████| 31/31 [00:08<00:00,  3.45it/s, loss=0.999, v_num=0, val_loss=0.826, train_loss_step=0.983, train_loss_epoch=1.000]
# Epoch 11:  97%|█████████▋| 30/31 [00:08<00:00,  3.60it/s, loss=0.989, v_num=0, val_loss=0.826, train_loss_step=0.936, train_loss_epoch=1.000]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 11: 100%|██████████| 31/31 [00:08<00:00,  3.48it/s, loss=0.989, v_num=0, val_loss=0.829, train_loss_step=0.990, train_loss_epoch=0.994]
# Epoch 12:  97%|█████████▋| 30/31 [00:08<00:00,  3.51it/s, loss=0.992, v_num=0, val_loss=0.829, train_loss_step=0.969, train_loss_epoch=0.994]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 12: 100%|██████████| 31/31 [00:09<00:00,  3.40it/s, loss=0.992, v_num=0, val_loss=0.840, train_loss_step=0.992, train_loss_epoch=0.987]
# Epoch 13:  97%|█████████▋| 30/31 [00:08<00:00,  3.63it/s, loss=0.961, v_num=0, val_loss=0.840, train_loss_step=0.936, train_loss_epoch=0.987]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 13: 100%|██████████| 31/31 [00:08<00:00,  3.48it/s, loss=0.961, v_num=0, val_loss=0.833, train_loss_step=0.991, train_loss_epoch=0.965]
# Epoch 14:  97%|█████████▋| 30/31 [00:08<00:00,  3.41it/s, loss=0.954, v_num=0, val_loss=0.833, train_loss_step=0.962, train_loss_epoch=0.965]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 14: 100%|██████████| 31/31 [00:09<00:00,  3.30it/s, loss=0.954, v_num=0, val_loss=0.821, train_loss_step=0.964, train_loss_epoch=0.960]
# Epoch 15:  97%|█████████▋| 30/31 [00:08<00:00,  3.41it/s, loss=0.931, v_num=0, val_loss=0.821, train_loss_step=0.946, train_loss_epoch=0.960]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 15: 100%|██████████| 31/31 [00:09<00:00,  3.29it/s, loss=0.931, v_num=0, val_loss=0.832, train_loss_step=0.945, train_loss_epoch=0.931]
# Epoch 16:  97%|█████████▋| 30/31 [00:08<00:00,  3.55it/s, loss=0.926, v_num=0, val_loss=0.832, train_loss_step=0.925, train_loss_epoch=0.931]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 16: 100%|██████████| 31/31 [00:09<00:00,  3.41it/s, loss=0.926, v_num=0, val_loss=0.829, train_loss_step=0.867, train_loss_epoch=0.921]
# Epoch 17:  97%|█████████▋| 30/31 [00:08<00:00,  3.60it/s, loss=0.882, v_num=0, val_loss=0.829, train_loss_step=0.888, train_loss_epoch=0.921]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 17: 100%|██████████| 31/31 [00:08<00:00,  3.48it/s, loss=0.882, v_num=0, val_loss=0.826, train_loss_step=0.962, train_loss_epoch=0.883]
# Epoch 18:  97%|█████████▋| 30/31 [00:08<00:00,  3.59it/s, loss=0.874, v_num=0, val_loss=0.826, train_loss_step=0.871, train_loss_epoch=0.883]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 18: 100%|██████████| 31/31 [00:08<00:00,  3.47it/s, loss=0.874, v_num=0, val_loss=0.843, train_loss_step=0.900, train_loss_epoch=0.881]
# Epoch 19:  97%|█████████▋| 30/31 [00:08<00:00,  3.56it/s, loss=0.867, v_num=0, val_loss=0.843, train_loss_step=0.890, train_loss_epoch=0.881]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 19: 100%|██████████| 31/31 [00:09<00:00,  3.43it/s, loss=0.867, v_num=0, val_loss=0.829, train_loss_step=0.908, train_loss_epoch=0.870]
# Epoch 20:  97%|█████████▋| 30/31 [00:08<00:00,  3.60it/s, loss=0.843, v_num=0, val_loss=0.829, train_loss_step=0.851, train_loss_epoch=0.870]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 20: 100%|██████████| 31/31 [00:08<00:00,  3.45it/s, loss=0.843, v_num=0, val_loss=0.826, train_loss_step=0.849, train_loss_epoch=0.856]
# Epoch 21:  97%|█████████▋| 30/31 [00:08<00:00,  3.62it/s, loss=0.837, v_num=0, val_loss=0.826, train_loss_step=0.849, train_loss_epoch=0.856]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 21: 100%|██████████| 31/31 [00:08<00:00,  3.49it/s, loss=0.837, v_num=0, val_loss=0.828, train_loss_step=0.817, train_loss_epoch=0.835]
# Epoch 22:  97%|█████████▋| 30/31 [00:08<00:00,  3.56it/s, loss=0.837, v_num=0, val_loss=0.828, train_loss_step=0.826, train_loss_epoch=0.835]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 22: 100%|██████████| 31/31 [00:09<00:00,  3.44it/s, loss=0.837, v_num=0, val_loss=0.825, train_loss_step=0.844, train_loss_epoch=0.837]
# Epoch 23:  97%|█████████▋| 30/31 [00:08<00:00,  3.57it/s, loss=0.843, v_num=0, val_loss=0.825, train_loss_step=0.780, train_loss_epoch=0.837]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 23: 100%|██████████| 31/31 [00:08<00:00,  3.45it/s, loss=0.843, v_num=0, val_loss=0.829, train_loss_step=0.799, train_loss_epoch=0.842]
# Epoch 24:  97%|█████████▋| 30/31 [00:08<00:00,  3.65it/s, loss=0.852, v_num=0, val_loss=0.829, train_loss_step=0.869, train_loss_epoch=0.842]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 24: 100%|██████████| 31/31 [00:08<00:00,  3.52it/s, loss=0.852, v_num=0, val_loss=0.850, train_loss_step=0.823, train_loss_epoch=0.847]
# Epoch 24: 100%|██████████| 31/31 [00:08<00:00,  3.52it/s, loss=0.852, v_num=0, val_loss=0.850, train_loss_step=0.823, train_loss_epoch=0.847]

# %%
best_model_path = trainer.checkpoint_callback.best_model_path
best_model = NBeats.load_from_checkpoint(best_model_path)

# %%
actuals = torch.cat([y[0] for x, y in iter(val_dataloader)])
predictions = best_model.predict(val_dataloader)
(actuals - predictions).abs().mean()
# Out:
# tensor(0.1847)

# %%
raw_predictions, x = best_model.predict(val_dataloader, mode="raw", return_x=True)

# %%
for idx in range(10):  # plot 10 examples
    best_model.plot_prediction(x, raw_predictions, idx=idx, add_loss_to_title=True);

# %%
for idx in range(10):  # plot 10 examples
    best_model.plot_interpretation(x, raw_predictions, idx=idx);
